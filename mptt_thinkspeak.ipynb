# %% [markdown]
# <a href="https://colab.research.google.com/github/lucio0723/thinksspeak_mqtt/blob/main/mptt_thinkspeak.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install paho-mqtt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.9/66.9 kB 1.0 MB/s eta 0:00:00
# ...

# %%
import json
import requests
n=0

def doit(topic, payload):
  global n
  print(topic, payload)
  j=json.loads(payload)
  #print(j['co2'])
  #url='https://api.thingspeak.com/update?api_key=MBXHFKNOS3NTXOGA'
  url='https://api.thingspeak.com/update?api_key=57ARJQB34UQFHF0O'
  url +='&field1='+j['co2']
  url +='&field2='+j['bme680'].split(',')[0]
  if n>15:
    r=requests.get(url)
    print(url, r.text)
    n=0
  n+=1

# %%
import paho.mqtt.client as mqtt

def on_connect(client, userdata, flags, reason_code, properties):
    print(f"Connected with result code {reason_code}")
    client.subscribe("connectware/indoor/data/1501")

def on_message(client, userdata, msg):
    doit(msg.topic, msg.payload.decode('utf8'))

client = mqtt.Client(mqtt.CallbackAPIVersion.VERSION2)
client.on_connect = on_connect
client.on_message = on_message

client.connect("damoa.io", 1883, 60)
client.loop_forever()
# Out:
# Connected with result code Success
# connectware/indoor/data/1501 {"dust":"30,36","co2":"403","bme680":"22.34,19.56,873944,100931,32.86","time":"2024-04-07 22:31:49", "serial":284762, "ip":"203.255.190.49"}
# connectware/indoor/data/1501 {"dust":"30,35","co2":"403","bme680":"22.34,19.56,873944,100932,32.77","time":"2024-04-07 22:31:50", "serial":284763, "ip":"203.255.190.49"}
# connectware/indoor/data/1501 {"dust":"30,34","co2":"404","bme680":"22.34,19.56,869987,100932,32.77","time":"2024-04-07 22:31:51", "serial":284764, "ip":"203.255.190.49"}
# connectware/indoor/data/1501 {"dust":"30,35","co2":"404","bme680":"22.34,19.57,876221,100932,32.77","time":"2024-04-07 22:31:52", "serial":284765, "ip":"203.255.190.49"}
# connectware/indoor/data/1501 {"dust":"30,35","co2":"404","bme680":"22.34,19.57,875081,100932,32.69","time":"2024-04-07 22:31:53", "serial":284766, "ip":"203.255.190.49"}
# ...
