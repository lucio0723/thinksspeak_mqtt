# %% [markdown]
# <a href="https://colab.research.google.com/github/lucio0723/thinksspeak_mqtt/blob/main/mqtt_client.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install paho-mqtt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.9/66.9 kB 1.1 MB/s eta 0:00:00
# ...

# %%
import paho.mqtt.client as mqtt

def on_connect(client, userdata, flags, reason_code, properties):
    print(f"Connected with result code {reason_code}")
    client.subscribe("connectware/indoor/data/#")

def on_message(client, userdata, msg):
    print(msg.topic, msg.payload.decode('utf8'))

client = mqtt.Client(mqtt.CallbackAPIVersion.VERSION2)
client.on_connect = on_connect
client.on_message = on_message

client.connect("damoa.io", 1883, 60)
client.loop_forever()
# Out:
# Connected with result code Success
# connectware/indoor/data/1503 {"dust":"21,23","co2":"399","bme680":"23.19,18.78,833855,100935,32.52","time":"2024-04-07 22:23:51", "serial":279734, "ip":"203.255.190.49"}
# connectware/indoor/data/1501 {"dust":"30,32","co2":"410","bme680":"22.37,19.44,889550,100933,32.60","time":"2024-04-07 22:23:51", "serial":284284, "ip":"203.255.190.49"}
# connectware/indoor/data/1502 {"dust":"30,34","co2":"543","bme680":"23.83,17.44,1581450,100976,29.10","time":"2024-04-07 22:23:52", "serial":279747, "ip":"203.255.190.49"}
# connectware/indoor/data/1503 {"dust":"21,23","co2":"399","bme680":"23.19,18.77,832290,100935,32.52","time":"2024-04-07 22:23:52", "serial":279735, "ip":"203.255.190.49"}
# connectware/indoor/data/1501 {"dust":"30,32","co2":"410","bme680":"22.37,19.44,888962,100933,32.77","time":"2024-04-07 22:23:52", "serial":284285, "ip":"203.255.190.49"}
# ...
